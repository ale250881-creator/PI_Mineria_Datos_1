# %%
import pandas as pd
import os

ruta = "../data/raw/streaming_users_dirty.json"
df = pd.read_json(ruta)

# 1. Dimensiones del dataset
print(f"Cantidad de registros (filas): {df.shape[0]}")
print(f"Cantidad de variables (columnas): {df.shape[1]}")

df.head()
# Out:
# Cantidad de registros (filas): 8160
# Cantidad de variables (columnas): 8
#    user_id  age subscription_plan  monthly_watch_time_mins   country  \
# 0    10000   39          Estándar                    805.8    Brasil
# 1    10001   37          Estándar                   1173.4  Colombia
# 2    10002   28            Básico                    401.0  Colombia
# 3    10003   43            Básico                     62.4   Uruguay
# 4    10004   51            Básico                    477.8      Perú
#
#   favorite_genre last_login_date  customer_support_tickets
# 0          Crime      2025-03-04                        99
# 1          Crime      2019-04-02                         2
# 2          Crime      2018-04-13                         0
# 3       Thriller      2021-01-31                         0
# 4       Thriller      2020-09-30                         1

# %%
list(df.columns)
# Out:
# ['user_id',
#  'age',
#  'subscription_plan',
#  'monthly_watch_time_mins',
#  'country',
#  'favorite_genre',
#  'last_login_date',
#  'customer_support_tickets']

# %%
df.dtypes
# Out:
# user_id                       int64
# age                           int64
# subscription_plan               str
# monthly_watch_time_mins     float64
# country                         str
# favorite_genre                  str
# last_login_date                 str
# customer_support_tickets      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8160 entries, 0 to 8159
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   user_id                   8160 non-null   int64
#  1   age                       8160 non-null   int64
#  2   subscription_plan         8160 non-null   str
#  3   monthly_watch_time_mins   7967 non-null   float64
#  4   country                   8160 non-null   str
#  5   favorite_genre            7920 non-null   str
#  6   last_login_date           7840 non-null   str
#  7   customer_support_tickets  8160 non-null   int64
# dtypes: float64(1), int64(3), str(4)
# memory usage: 510.1 KB

# %%
df.describe()
# Out:
#             user_id          age  monthly_watch_time_mins  \
# count   8160.000000  8160.000000              7967.000000
# mean   13995.433824    34.096814              1107.346153
# std     2310.810660    14.511304              5310.442604
# min    10000.000000    -5.000000              -120.000000
# 25%    11987.750000    25.000000               489.200000
# 50%    13998.500000    33.000000               757.400000
# 75%    15997.250000    42.000000              1045.700000
# max    17999.000000   150.000000             99999.000000
#
#        customer_support_tickets
# count               8160.000000
# mean                   1.800980
# std                   11.334969
# min                   -1.000000
# 25%                    0.000000
# 50%                    1.000000
# 75%                    1.000000
# max                  150.000000

# %%
df.describe(include="object")
# Out:
# C:\Users\Ale\AppData\Local\Temp\ipykernel_8756\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        subscription_plan country favorite_genre last_login_date
# count               8160    8160           7920            7840
# unique                15      26             28            3062
# top               Básico  Brasil        Comedia      2026-15-03
# freq                3450    1132           1112              20

# %%
df.isnull().sum()
# Out:
# user_id                       0
# age                           0
# subscription_plan             0
# monthly_watch_time_mins     193
# country                       0
# favorite_genre              240
# last_login_date             320
# customer_support_tickets      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(126)

# %%
df.nunique()
# Out:
# user_id                     8000
# age                           69
# subscription_plan             15
# monthly_watch_time_mins     5788
# country                       26
# favorite_genre                28
# last_login_date             3062
# customer_support_tickets       9
# dtype: int64

# %%
df["subscription_plan"].value_counts(dropna=False)
# Out:
# subscription_plan
# Básico       3450
# Estándar     2711
# Premium      1519
# basico         60
# BASICO         52
# Basic          52
# básico         50
# Std            48
# Estándar       46
# estandar       36
# STANDARD       34
# Premium        31
# PREMIUM        26
# Premiun        23
# premium        22
# Name: count, dtype: int64

# %%
log = [{
    'Paso': 0,
    'Descripción': 'Dataset original (carga e inspección inicial, sin modificaciones)',
    'Filas': len(df),
    'Nulos': int(df.isnull().sum().sum()),
    'Retención (%)': 100.0
}]

pd.DataFrame(log).to_csv('../logs/pipeline_log.csv', index=False)
pd.DataFrame(log)
# Out:
#    Paso                                        Descripción  Filas  Nulos  \
# 0     0  Dataset original (carga e inspección inicial, ...   8160    753
#
#    Retención (%)
# 0          100.0
